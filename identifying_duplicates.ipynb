# %%
data=pd.read_pickle('pickels/28k_apparel_data')
#loading data from pickles folder

# %% [markdown]
# ## Removing duplicate items

# %% [markdown]
# ### Identifying duplicate items

# %%
#find no.of products that have duplicate titles
#title is used as a feature because during analysis of dataset, it was found that all 183138 products contain title
print(sum(data.duplicated('title')))
#2325 products have same title but may differ in other features like color,size
# Out:
# 2325

# %% [markdown]
# ## The following products have same 'title' but different 'asin' (Amazon Std Identification Number) and             different 'sizes'. In simple words, the products are the exactly same except varying sizes:

# %%
from IPython.display import Image
Image(filename='dedupe/B00AQ4GMCK.jpeg')

# %% [markdown]
# Size: S

# %%
Image(filename='dedupe/B00AQ4GMLQ.jpeg')

# %% [markdown]
# Size: M

# %%
Image(filename='dedupe/B00AQ4GMTS.jpeg')

# %% [markdown]
# Size: L

# %%
Image(filename='dedupe/B00AQ4GN3I.jpeg')

# %% [markdown]
# Size: XL

# %% [markdown]
# ## The following products have same 'title' but different 'asin' (Amazon Std Identification Number) and different 'colors'. In simple words, the products are the exactly same except varying colors:

# %%
Image(filename='dedupe/B00G278GZ6.jpeg')

# %% [markdown]
# Color: Blue

# %%
Image(filename='dedupe/B00G278W6O.jpeg')

# %% [markdown]
# Color: Light Green

# %%
Image(filename='dedupe/B00G278Z2A.jpeg')

# %% [markdown]
# Color: Pink

# %%
Image(filename='dedupe/B00G2786X8.jpeg')

# %% [markdown]
# Color: Orange
